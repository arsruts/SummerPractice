# %%
# !pip install jupyter-dash
# Out:
# ...
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\а\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\а\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\а\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\а\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\а\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages)
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('final_res_edited.csv', encoding='utf-16', error_bad_lines=False, sep=' ')
df
# Out:
#     Unnamed: 0                                               Name  \
# 0            0  Новая концепция для музея «Микула» в Нижнем Но...
# 1            1  Развитие туристического кластера в Кроноцком з...
# 2            2  Создание мобильного приложения СППР для диагно...
# 3            3                       Гуманитарная политика России
# 4            4         Подкаст про современное высшее образование
# 5            5  Экспедиция "Миграционные процессы в регионах и...
# 6            6     Медиацентр факультета биологии и биотехнологии
# 7            7  Прошлое как ресурс формирования новых городски...
# 8            8  Международный проект с Даляньским университето...
# 9            9  Создание экотропы у озера Щелкунское (Свердлов...
# 10          10  Развитие кросс-платформенной музыкально-издате...
# 11          11  Создание образовательной программы «Резиденция...
# 12          12  Информационная поддержка деятельности ПУЛАП в ...
# ...

# %%
from dash import Dash, dcc, html, Input, Output
import plotly.express as px

app = Dash(__name__)

colors = {
    'background': '#111111',
    'text': '#7FDBFF'
}

grouped = df.groupby(['Amount of credits']).count()

labels = grouped.index
values = grouped['Name'].values

fig = px.bar(df, x=labels, y=values, text = values)

fig.update_layout(
    title = 'Number of Projects by Credits',
    xaxis_title = 'Amount of Credits',
    yaxis_title = 'Number of Projects'
)

app.layout = html.Div(children=[
    html.H1(children='Hello Dash'),

    html.Div(children='''
        Dash: A web application framework for your data.
    '''),

    dcc.Graph(
        id='example-graph',
        figure=fig
    )
])

if __name__ == '__main__':
    app.run_server(debug=False)

# %%
from dash import Dash, dcc, html, Input, Output
import plotly.express as px

app = Dash(__name__)

colors = {
    'background': '#111111',
    'text': '#7FDBFF'
}

grouped = df.groupby(['Course']).count()

labels = grouped.index
values = grouped['Name'].values

fig = px.bar(df, x=values, y=labels, text = values)

fig.update_layout(
    title = 'Number of Projects by Courses',
    xaxis_title = 'Courses',
    yaxis_title = 'Number of Projects',
)

fig.update_traces(marker_color='MediumPurple')

app.layout = html.Div(children=[
    html.H1(children='Hello Dash'),

    html.Div(children='''
        Dash: A web application framework for your data.
    '''),

    dcc.Graph(
        id='example-graph',
        figure=fig
    )
])

if __name__ == '__main__':
    app.run_server(debug=False)

# %%
from dash import Dash, dcc, html, Input, Output
import plotly.graph_objs as go

app = Dash(__name__)

colors = {
    'background': '#111111',
    'text': '#7FDBFF'
}

grouped = df.groupby(['Campus']).count()

labels = grouped.index
values = grouped['Name'].values

fig = go.Figure()
fig.add_trace(go.Pie(values=values, labels=labels, hole=0.5))

fig.update_layout(
    title = 'Number of Projects by Campuses'
)

app.layout = html.Div(children=[
    html.H1(children='Hello Dash',
            style={'textAlign': 'center'}),

    html.Div(children='Dash: A web application framework for your data.'),

    dcc.Graph(
        id='example-graph',
        figure=fig
    )
])

if __name__ == '__main__':
    app.run_server(debug=False)
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:8050
# Press CTRL+C to quit
# 127.0.0.1 - - [01/Sep/2022 03:51:43] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Sep/2022 03:51:44] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Sep/2022 03:51:44] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Sep/2022 03:51:44] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 304 -
# 127.0.0.1 - - [01/Sep/2022 03:51:44] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 304 -
